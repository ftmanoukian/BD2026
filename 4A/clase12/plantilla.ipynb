# %% [markdown]
# # Actividad: pandas + datos abiertos de CABA
#
# Completen este notebook en grupo.
#
# El objetivo es responder una pregunta sencilla usando un dataset real.

# %% [markdown]
# ## 1. Importar pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Cargar el archivo
#
# Primero suban el archivo CSV a Colab.
#
# Luego cambien el nombre del archivo en la siguiente celda.

# %%
df = pd.read_csv("NOMBRE_DEL_ARCHIVO.csv")

# %% [markdown]
# ## 3. Mirar las primeras filas
#
# ¿Qué representa cada fila del dataset?

# %%
df.head()

# %% [markdown]
# Escriban acá:
#
# **Cada fila representa:**
# ...

# %% [markdown]
# ## 4. Mirar columnas disponibles

# %%
df.columns

# %% [markdown]
# Escriban acá algunas columnas que podrían servir:
#
# - ...
# - ...
# - ...

# %% [markdown]
# ## 5. Tamaño del dataset

# %%
df.shape

# %% [markdown]
# ## 6. Hipótesis o pregunta
#
# Elijan una pregunta sencilla.
#
# Ejemplos:
#
# - ¿Cuál es la categoría más frecuente?
# - ¿Qué comuna/barrio/tipo aparece más veces?
# - ¿Hay muchas diferencias entre categorías?
# - ¿Cuáles son los 10 valores más comunes?
#
# **Nuestra hipótesis o pregunta es:**
# ...

# %% [markdown]
# ## 7. Elegimos una columna para contar
#
# Cambien `COLUMNA` por el nombre real de la columna.

# %%
conteo = df["COLUMNA"].value_counts()

conteo

# %% [markdown]
# ## 8. Hacemos un gráfico simple
#
# Si hay demasiados valores, usen `.head(10)` para mostrar solo los 10 primeros.

# %%
conteo.head(10).plot(kind="bar", title="Resultado")

# %% [markdown]
# ## 9. Conclusión
#
# Respondan en palabras simples.
#
# **El resultado muestra que:**
# ...
#
# **Nuestra hipótesis:**
# - se cumple
# - no se cumple
# - no se puede responder con este dataset
#
# **Conclusión final:**
# ...

# %% [markdown]
# ## 10. Extra opcional
#
# Solo para grupos que quieran avanzar un poco más.
#
# ### Promedio por categoría
#
# Sirve si tienen una columna categórica y una columna numérica.
#
# Ejemplo:
#
# ```python
# df.groupby("COLUMNA_CATEGORIA")["COLUMNA_NUMERICA"].mean()
# ```

# %%
# Extra opcional:
# promedio = df.groupby("COLUMNA_CATEGORIA")["COLUMNA_NUMERICA"].mean()
# promedio

# %%
# Extra opcional:
# promedio.sort_values().plot(kind="bar")
