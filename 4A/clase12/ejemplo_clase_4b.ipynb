# %% [markdown]
# # Mi primer notebook de Google Colab!
#
# Esto es un cuadro de texto

# %% [markdown]
# # Si utilizo un numeral (#) creo un título
#
# ## Con dos (##), creo un subtítulo
#
# Y así...

# %% [markdown]
# Con dos asteriscos a cada lado de la palabra, queda en **negrita**
#
# Con uno solo a cada lado, queda en *itálica*
#
# Si uso un guión o un asterisco a la izquierda:
# * creo
# * una
# * lista

# %% [markdown]
# Se pueden seguir buscando más recursos en internet con el nombre del lenguaje: **Markdown**

# %%
a = 10
b = 15

a + b
# Out:
# 25

# %% [markdown]
# El código que se corre en diferentes celdas, comparte variables:

# %%
a - b
# Out:
# -5

# %% [markdown]
# Sin embargo, el orden de **ejecución** es importante: Las celdas no corren automáticamente, sino que hay que ejecutarlas. Las celdas que ejecutemos primero van a ir almacenando gradualmente sus valores de variables, etc.
#
# En la siguiente celda, voy a usar un valor que todavía no creé:

# %%
c + d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4123/3472337998.py in <cell line: 0>()
# ----> 1 c + d
#
# NameError: name 'c' is not defined

# %% [markdown]
# Como vemos, esto nos tira un error. A continuación, voy a repetir la celda anterior, pero **no** la voy a correr hasta después de ejecutar la celda que le sigue:

# %%
c + d
# Out:
# 28

# %% [markdown]
# blablablablablablablablablablabla

# %%
c = 3
d = a + b
