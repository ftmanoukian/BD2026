# %% [markdown]
# # Actividad: análisis de datos abiertos con pandas
#
# Completen este notebook en grupos.
#
# Dataset elegido: **escribir acá el nombre del dataset**

# %% [markdown]
# ## 1. Importar módulos

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Cargar archivo CSV
#
# Suban el archivo descargado desde Buenos Aires Data.

# %%
from google.colab import files

uploaded = files.upload()
filename = list(uploaded.keys())[0]
filename

# %%
df = pd.read_csv(filename)
df.head()

# %% [markdown]
# ## 3. Entender el dataset
#
# Responder:
#
# - ¿Qué representa cada fila?
# - ¿Cuáles son las columnas más importantes?
# - ¿Hay columnas categóricas?
# - ¿Hay columnas numéricas?
# - ¿Hay columnas de fecha o tiempo?

# %%
df.shape

# %%
df.info()

# %%
df.columns

# %%
df.head(10)

# %% [markdown]
# ## 4. Revisión inicial de calidad de datos

# %%
df.nunique().sort_values()

# %%
df.isna().mean().sort_values(ascending=False).head(20)

# %% [markdown]
# ## 5. Exploración inicial
#
# Cambien los nombres de columnas según el dataset que hayan elegido.

# %%
# Ejemplo para una columna categórica:
# df["nombre_de_columna"].value_counts().head(10)

# %%
# Ejemplo de agrupamiento:
# df.groupby("columna_grupo").size().sort_values(ascending=False)

# %%
# Ejemplo de promedio por grupo:
# df.groupby("columna_grupo")["columna_numerica"].mean().sort_values(ascending=False)

# %%
# Ejemplo de filtro:
# df[df["columna_numerica"] > 10]

# %% [markdown]
# ## 6. Hipótesis 1
#
# **Hipótesis:** escribir acá la primera hipótesis.
#
# **Columnas necesarias:** escribir qué columnas van a usar.
#
# **Método:** explicar qué operación de pandas van a usar.

# %%
# Código para verificar la hipótesis 1

# %% [markdown]
# **Conclusión de la hipótesis 1:**
#
# Escribir si la hipótesis se cumple, no se cumple o no se puede verificar con este dataset.

# %% [markdown]
# ## 7. Hipótesis 2
#
# **Hipótesis:** escribir acá la segunda hipótesis.
#
# **Columnas necesarias:** escribir qué columnas van a usar.
#
# **Método:** explicar qué operación de pandas van a usar.

# %%
# Código para verificar la hipótesis 2

# %% [markdown]
# **Conclusión de la hipótesis 2:**
#
# Escribir si la hipótesis se cumple, no se cumple o no se puede verificar con este dataset.

# %% [markdown]
# ## 8. Hipótesis 3 opcional
#
# Usar solo si tienen una tercera hipótesis clara y verificable.

# %%
# Código para una tercera hipótesis, si corresponde

# %% [markdown]
# ## 9. Conclusión general
#
# Responder:
#
# - ¿Qué aprendieron del dataset?
# - ¿Qué hipótesis fue más fácil de verificar?
# - ¿Qué limitaciones tuvieron los datos?
# - ¿Qué no se puede afirmar con este análisis?
